# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import sys
import urllib
from googleapiclient.discovery import build
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from datetime import datetime, timedelta
import time
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../Data/OSG_Podcast_Data2024-02-14.csv')
df['Streams (S)'] = df['Streams (S)'].str.replace(',', '').astype(float)

# %%
df['Date Collected'] = pd.to_datetime(df['Date Collected'], format='%m/%d/%y', errors='coerce')
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Table for Total Plays

# %%
most_recent_date = df["Date Collected"].max()
most_recent = df[df["Date Collected"] == most_recent_date]

# %%
sorted_df = most_recent.sort_values(by="Total Combined Plays", ascending=False)
sorted_df["Rank"] = range(1, len(sorted_df) + 1)
Total_plays_df = sorted_df[["Rank", "Episode Title", "Total Combined Plays", "Date"]]
Total_plays_df
# Out:
#     Rank  \
# 23     1
# 34     2
# 11     3
# 20     4
# 27     5
# 16     6
# 33     7
# 14     8
# 15     9
# 18    10
# 17    11
# 40    12
# 28    13
# 22    14
# 8     15
# 12    16
# 7     17
# 21    18
# 39    19
# 29    20
# 9     21
# 32    22
# 19    23
# 43    24
# 1     25
# 2     26
# 24    27
# 31    28
# 3     29
# 6     30
# 10    31
# 25    32
# 5     33
# 13    34
# 42    35
# 26    36
# 38    37
# 45    38
# 41    39
# 37    40
# 4     41
# 30    42
# 46    43
# 0     44
# 35    45
# 47    46
# 44    47
# 36    48
#
#                                                                           Episode Title  \
# 23                                             David Brooks: What is a Meaningful Life?
# 34                                 Dr. Tracy Dennis-Tiwary: Can Anxiety Be Good For Us?
# 11                                       Dr. Rachel Naomi Remen: Can We All Be Healers?
# 20                                                   You’re Not Alone in Feeling Lonely
# 27                            Dr. Marisa G. Franco: Why Do Friendships Matter? (Part 2)
# 16                                        Meet My Moai, A Powerful Friendship Tradition
# 33                                          Bonus: Meditation for Easing Holiday Stress
# 14                             Rainn Wilson: Walking A Spiritual Path In A Lonely World
# 15                      Richard Reeves: Why Are Boys And Men Struggling For Connection?
# 18                              Dr. Lisa Damour: How Can We Protect Teen Mental Health?
# 17                                   Judy Woodruff: What Does It Mean To Really Listen?
# 40                                              Dr. Laurie Santos: What Makes Us Happy?
# 28                                   Bonus: Meditation for Getting Through a Hectic Day
# 22  Dr. Rangan Chatterjee: How Stressed Are We? (And What Can We Do About It?) (Part 1)
# 8                        Baratunde Thurston: What Can Nature Teach Us About Connection?
# 12           Encore | Susan Cain: How Do We Navigate the Joy and Sorrow of Being Human?
# 7                                                 Yo-Yo Ma: How Music Heals Us (Part 1)
# 21                Dr. Rangan Chatterjee: What's at the Core of Your Happiness? (Part 2)
# 39                                         Kal Penn: Taking the Path of Most Resistance
# 29                            Dr. Marisa G. Franco: Why Do Friendships Matter? (Part 1)
# 9                                          Ashley Judd & Friends: Finding Chosen Family
# 32                                           Bonus: Meditation for Combating Loneliness
# 19                    Eric Nam: Yes, Vulnerability is a Superpower (Even For Pop Stars)
# 43                                 Father Greg Boyle: Finding Strength Through Kindness
# 1                     Dr. Lisa Miller: How Does Spirituality Protect Our Mental Health?
# 2                              Jon Batiste: How Do You Build the Confidence to Connect?
# 24                                    Catherine Price: Can You Live Without Your Phone?
# 31                                                 Maya Shankar: Why is Change So Hard?
# 3                                   Matthew McConaughey: What Does Success Really Mean?
# 6                                                 Yo-Yo Ma: How Music Heals Us (Part 2)
# 10                        Encore | Dr. Tracy Dennis-Tiwary: Can Anxiety Be Good For Us?
# 25                                                                 What Gives You Hope?
# 5                        Encore (Student Edition) | Laurie Santos: What Makes Us Happy?
# 13                                          Encore | José Andrés: Recipe for Connection
# 42                               Jon Kabat-Zinn: Peace and the Domain of Being (Part 1)
# 26                           Bonus: Meditation for Dealing with Negativity in the World
# 38                    Susan Cain: How Do We Navigate the Joy and Sorrow of Being Human?
# 45                                  Kate Bowler: Learning to Live When Life Falls Apart
# 41                         Jon Kabat-Zinn: Clarity and the Domain of Stillness (Part 2)
# 37                                  Dr. Becky Kennedy: How Do We Connect With Our Kids?
# 4                                                                 How Will You Connect?
# 30                              Bonus: Meditation for Dealing with Change & Uncertainty
# 46                                                   José Andrés: Recipe for Connection
# 0                                             Meditation for Connecting with Loved Ones
# 35                                                              Fred Dust: Can We Talk?
# 47                                         Welcome to House Calls with Dr. Vivek Murthy
# 44                        Christian Robinson: Why Feeling Like We Matter Really Matters
# 36     Dr. Rosaura Orengo-Aguayo: What Do Natural Disasters Mean for Our Mental Health?
#
#     Total Combined Plays        Date
# 23               22509.0  03-21-2023
# 34               17160.0  12-13-2022
# 11               14601.0  09-05-2023
# 20               12485.0  05-02-2023
# 27               11484.0  02-07-2023
# 16               11339.0  06-27-2023
# 33               11019.0  12-20-2022
# 14               10770.0  07-25-2023
# 15               10577.0  07-11-2023
# 18               10305.0  05-30-2023
# 17               10194.0  06-13-2023
# 40               10173.0  09-20-2022
# 28                9890.0  01-31-2023
# 22                9743.0  04-04-2023
# 8                 8833.0  10-17-2023
# 12                8720.0  08-22-2023
# 7                 8583.0  10-31-2023
# 21                8539.0  04-18-2023
# 39                8412.0  10-04-2022
# 29                8378.0  01-24-2023
# 9                 8281.0  10-03-2023
# 32                8246.0  01-04-2023
# 19                8139.0  05-16-2023
# 43                8009.0  08-09-2022
# 1                 7924.0  01-24-2024
# 2                 7652.0  01-10-2024
# 24                7370.0  03-07-2023
# 31                7349.0  01-10-2023
# 3                 7316.0  12-13-2023
# 6                 6634.0  11-15-2023
# 10                6519.0  09-19-2023
# 25                6205.0  02-22-2023
# 5                 6065.0  11-29-2023
# 13                5798.0  08-09-2023
# 42                5771.0  08-24-2022
# 26                5491.0  02-15-2023
# 38                5289.0  10-18-2022
# 45                5164.0  07-13-2022
# 41                5149.0  09-06-2022
# 37                5080.0  11-01-2022
# 4                 4983.0  12-06-2023
# 30                4641.0  01-17-2023
# 46                4350.0  06-29-2022
# 0                 3737.0  02-07-2024
# 35                3155.0  11-29-2022
# 47                3065.0  06-21-2022
# 44                2892.0  07-27-2022
# 36                2258.0  11-15-2022

# %% [markdown]
# # Table for Top 20 youtube plays

# %%
sorted_df = most_recent.sort_values(by="Total YouTube Plays", ascending=False)
sorted_df["Rank"] = range(1, len(sorted_df) + 1)
Top20_YT_plays_df = sorted_df.nlargest(20, "Total YouTube Plays")[["Rank", "Episode Title", "Total YouTube Plays", "Date"]]
Top20_YT_plays_df
# Out:
#     Rank  \
# 34     1
# 33     2
# 27     3
# 23     4
# 28     5
# 32     6
# 39     7
# 20     8
# 29     9
# 31    10
# 43    11
# 11    12
# 40    13
# 26    14
# 25    15
# 16    16
# 30    17
# 22    18
# 24    19
# 41    20
#
#                                                                           Episode Title  \
# 34                                 Dr. Tracy Dennis-Tiwary: Can Anxiety Be Good For Us?
# 33                                          Bonus: Meditation for Easing Holiday Stress
# 27                            Dr. Marisa G. Franco: Why Do Friendships Matter? (Part 2)
# 23                                             David Brooks: What is a Meaningful Life?
# 28                                   Bonus: Meditation for Getting Through a Hectic Day
# 32                                           Bonus: Meditation for Combating Loneliness
# 39                                         Kal Penn: Taking the Path of Most Resistance
# 20                                                   You’re Not Alone in Feeling Lonely
# 29                            Dr. Marisa G. Franco: Why Do Friendships Matter? (Part 1)
# 31                                                 Maya Shankar: Why is Change So Hard?
# 43                                 Father Greg Boyle: Finding Strength Through Kindness
# 11                                       Dr. Rachel Naomi Remen: Can We All Be Healers?
# 40                                              Dr. Laurie Santos: What Makes Us Happy?
# 26                           Bonus: Meditation for Dealing with Negativity in the World
# 25                                                                 What Gives You Hope?
# 16                                        Meet My Moai, A Powerful Friendship Tradition
# 30                              Bonus: Meditation for Dealing with Change & Uncertainty
# 22  Dr. Rangan Chatterjee: How Stressed Are We? (And What Can We Do About It?) (Part 1)
# 24                                    Catherine Price: Can You Live Without Your Phone?
# 41                         Jon Kabat-Zinn: Clarity and the Domain of Stillness (Part 2)
#
#     Total YouTube Plays        Date
# 34              15181.0  12-13-2022
# 33              10078.0  12-20-2022
# 27               9152.0  02-07-2023
# 23               8780.0  03-21-2023
# 28               8545.0  01-31-2023
# 32               7106.0  01-04-2023
# 39               5917.0  10-04-2022
# 20               5758.0  05-02-2023
# 29               5490.0  01-24-2023
# 31               5182.0  01-10-2023
# 43               4306.0  08-09-2022
# 11               4246.0  09-05-2023
# 40               4148.0  09-20-2022
# 26               3941.0  02-15-2023
# 25               3861.0  02-22-2023
# 16               3408.0  06-27-2023
# 30               3344.0  01-17-2023
# 22               3189.0  04-04-2023
# 24               2768.0  03-07-2023
# 41               2745.0  09-06-2022

# %% [markdown]
# # Table for Top 20 Podcast Plays

# %%
sorted_df = most_recent.sort_values(by="Total Podcast Plays", ascending=False)
sorted_df["Rank"] = range(1, len(sorted_df) + 1)
Top20_pod_plays_df = sorted_df.nlargest(20, "Total Podcast Plays")[["Rank", "Episode Title", "Total Podcast Plays", "Date"]]
Top20_pod_plays_df
# Out:
#     Rank  \
# 23     1
# 11     2
# 14     3
# 12     4
# 18     5
# 8      6
# 15     7
# 17     8
# 16     9
# 9     10
# 7     11
# 1     12
# 20    13
# 2     14
# 19    15
# 22    16
# 10    17
# 3     18
# 6     19
# 40    20
#
#                                                                           Episode Title  \
# 23                                             David Brooks: What is a Meaningful Life?
# 11                                       Dr. Rachel Naomi Remen: Can We All Be Healers?
# 14                             Rainn Wilson: Walking A Spiritual Path In A Lonely World
# 12           Encore | Susan Cain: How Do We Navigate the Joy and Sorrow of Being Human?
# 18                              Dr. Lisa Damour: How Can We Protect Teen Mental Health?
# 8                        Baratunde Thurston: What Can Nature Teach Us About Connection?
# 15                      Richard Reeves: Why Are Boys And Men Struggling For Connection?
# 17                                   Judy Woodruff: What Does It Mean To Really Listen?
# 16                                        Meet My Moai, A Powerful Friendship Tradition
# 9                                          Ashley Judd & Friends: Finding Chosen Family
# 7                                                 Yo-Yo Ma: How Music Heals Us (Part 1)
# 1                     Dr. Lisa Miller: How Does Spirituality Protect Our Mental Health?
# 20                                                   You’re Not Alone in Feeling Lonely
# 2                              Jon Batiste: How Do You Build the Confidence to Connect?
# 19                    Eric Nam: Yes, Vulnerability is a Superpower (Even For Pop Stars)
# 22  Dr. Rangan Chatterjee: How Stressed Are We? (And What Can We Do About It?) (Part 1)
# 10                        Encore | Dr. Tracy Dennis-Tiwary: Can Anxiety Be Good For Us?
# 3                                   Matthew McConaughey: What Does Success Really Mean?
# 6                                                 Yo-Yo Ma: How Music Heals Us (Part 2)
# 40                                              Dr. Laurie Santos: What Makes Us Happy?
#
#     Total Podcast Plays        Date
# 23                13729  03-21-2023
# 11                10355  09-05-2023
# 14                 8921  07-25-2023
# 12                 8720  08-22-2023
# 18                 8602  05-30-2023
# 8                  8210  10-17-2023
# 15                 8079  07-11-2023
# 17                 7964  06-13-2023
# 16                 7931  06-27-2023
# 9                  7674  10-03-2023
# 7                  7051  10-31-2023
# 1                  6977  01-24-2024
# 20                 6727  05-02-2023
# 2                  6700  01-10-2024
# 19                 6590  05-16-2023
# 22                 6554  04-04-2023
# 10                 6519  09-19-2023
# 3                  6452  12-13-2023
# 6                  6110  11-15-2023
# 40                 6025  09-20-2022

# %% [markdown]
# # Table for Apple Engaged Listeners

# %%
sorted_df = most_recent.sort_values(by="Unique Engaged Listeners (A)", ascending=False)
sorted_df["Rank"] = range(1, len(sorted_df) + 1)
Engaged_listens_df = sorted_df[["Rank", "Episode Title", "Unique Engaged Listeners (A)"]]
Engaged_listens_df
# Out:
#     Rank  \
# 23     1
# 11     2
# 7      3
# 22     4
# 14     5
# 20     6
# 21     7
# 12     8
# 17     9
# 8     10
# 18    11
# 3     12
# 16    13
# 6     14
# 9     15
# 2     16
# 1     17
# 15    18
# 10    19
# 13    20
# 19    21
# 4     22
# 24    23
# 5     24
# 25    25
# 42    26
# 29    27
# 43    28
# 0     29
# 27    30
# 37    31
# 26    32
# 31    33
# 45    34
# 41    35
# 47    36
# 38    37
# 40    38
# 46    39
# 35    40
# 28    41
# 39    42
# 34    43
# 44    44
# 30    45
# 32    46
# 36    47
# 33    48
#
#                                                                           Episode Title  \
# 23                                             David Brooks: What is a Meaningful Life?
# 11                                       Dr. Rachel Naomi Remen: Can We All Be Healers?
# 7                                                 Yo-Yo Ma: How Music Heals Us (Part 1)
# 22  Dr. Rangan Chatterjee: How Stressed Are We? (And What Can We Do About It?) (Part 1)
# 14                             Rainn Wilson: Walking A Spiritual Path In A Lonely World
# 20                                                   You’re Not Alone in Feeling Lonely
# 21                Dr. Rangan Chatterjee: What's at the Core of Your Happiness? (Part 2)
# 12           Encore | Susan Cain: How Do We Navigate the Joy and Sorrow of Being Human?
# 17                                   Judy Woodruff: What Does It Mean To Really Listen?
# 8                        Baratunde Thurston: What Can Nature Teach Us About Connection?
# 18                              Dr. Lisa Damour: How Can We Protect Teen Mental Health?
# 3                                   Matthew McConaughey: What Does Success Really Mean?
# 16                                        Meet My Moai, A Powerful Friendship Tradition
# 6                                                 Yo-Yo Ma: How Music Heals Us (Part 2)
# 9                                          Ashley Judd & Friends: Finding Chosen Family
# 2                              Jon Batiste: How Do You Build the Confidence to Connect?
# 1                     Dr. Lisa Miller: How Does Spirituality Protect Our Mental Health?
# 15                      Richard Reeves: Why Are Boys And Men Struggling For Connection?
# 10                        Encore | Dr. Tracy Dennis-Tiwary: Can Anxiety Be Good For Us?
# 13                                          Encore | José Andrés: Recipe for Connection
# 19                    Eric Nam: Yes, Vulnerability is a Superpower (Even For Pop Stars)
# 4                                                                 How Will You Connect?
# 24                                    Catherine Price: Can You Live Without Your Phone?
# 5                        Encore (Student Edition) | Laurie Santos: What Makes Us Happy?
# 25                                                                 What Gives You Hope?
# 42                               Jon Kabat-Zinn: Peace and the Domain of Being (Part 1)
# 29                            Dr. Marisa G. Franco: Why Do Friendships Matter? (Part 1)
# 43                                 Father Greg Boyle: Finding Strength Through Kindness
# 0                                             Meditation for Connecting with Loved Ones
# 27                            Dr. Marisa G. Franco: Why Do Friendships Matter? (Part 2)
# 37                                  Dr. Becky Kennedy: How Do We Connect With Our Kids?
# 26                           Bonus: Meditation for Dealing with Negativity in the World
# 31                                                 Maya Shankar: Why is Change So Hard?
# 45                                  Kate Bowler: Learning to Live When Life Falls Apart
# 41                         Jon Kabat-Zinn: Clarity and the Domain of Stillness (Part 2)
# 47                                         Welcome to House Calls with Dr. Vivek Murthy
# 38                    Susan Cain: How Do We Navigate the Joy and Sorrow of Being Human?
# 40                                              Dr. Laurie Santos: What Makes Us Happy?
# 46                                                   José Andrés: Recipe for Connection
# 35                                                              Fred Dust: Can We Talk?
# 28                                   Bonus: Meditation for Getting Through a Hectic Day
# 39                                         Kal Penn: Taking the Path of Most Resistance
# 34                                 Dr. Tracy Dennis-Tiwary: Can Anxiety Be Good For Us?
# 44                        Christian Robinson: Why Feeling Like We Matter Really Matters
# 30                              Bonus: Meditation for Dealing with Change & Uncertainty
# 32                                           Bonus: Meditation for Combating Loneliness
# 36     Dr. Rosaura Orengo-Aguayo: What Do Natural Disasters Mean for Our Mental Health?
# 33                                          Bonus: Meditation for Easing Holiday Stress
#
#     Unique Engaged Listeners (A)
# 23                        2783.0
# 11                        1898.0
# 7                         1794.0
# 22                        1772.0
# 14                        1629.0
# 20                        1608.0
# 21                        1543.0
# 12                        1493.0
# 17                        1476.0
# 8                         1337.0
# 18                        1275.0
# 3                         1263.0
# 16                        1234.0
# 6                         1181.0
# 9                         1176.0
# 2                         1169.0
# 1                         1164.0
# 15                        1144.0
# 10                        1108.0
# 13                        1003.0
# 19                         998.0
# 4                          988.0
# 24                         880.0
# 5                          861.0
# 25                         815.0
# 42                         795.0
# 29                         760.0
# 43                         703.0
# 0                          692.0
# 27                         591.0
# 37                         557.0
# 26                         553.0
# 31                         539.0
# 45                         534.0
# 41                         517.0
# 47                         512.0
# 38                         505.0
# 40                         497.0
# 46                         460.0
# 35                         416.0
# 28                         402.0
# 39                         366.0
# 34                         355.0
# 44                         350.0
# 30                         340.0
# 32                         296.0
# 36                         178.0
# 33                         178.0

# %% [markdown]
# # Table for Times Played

# %%
sorted_df = most_recent.sort_values(by="Times Played", ascending=False)
sorted_df["Rank"] = range(1, len(sorted_df) + 1)
Times_fully_played_df = sorted_df[["Rank", "Episode Title", "Times Played"]]
Times_fully_played_df.rename(columns={'Times Played': 'Times Fully Played'}, inplace=True)
Times_fully_played_df
# Out:
#     Rank  \
# 23     1
# 11     2
# 22     3
# 7      4
# 20     5
# 21     6
# 14     7
# 12     8
# 17     9
# 18    10
# 3     11
# 16    12
# 40    13
# 2     14
# 15    15
# 9     16
# 1     17
# 6     18
# 8     19
# 10    20
# 19    21
# 42    22
# 43    23
# 24    24
# 13    25
# 29    26
# 4     27
# 47    28
# 5     29
# 25    30
# 45    31
# 46    32
# 27    33
# 41    34
# 0     35
# 31    36
# 26    37
# 37    38
# 38    39
# 35    40
# 28    41
# 34    42
# 39    43
# 30    44
# 44    45
# 32    46
# 33    47
# 36    48
#
#                                                                           Episode Title  \
# 23                                             David Brooks: What is a Meaningful Life?
# 11                                       Dr. Rachel Naomi Remen: Can We All Be Healers?
# 22  Dr. Rangan Chatterjee: How Stressed Are We? (And What Can We Do About It?) (Part 1)
# 7                                                 Yo-Yo Ma: How Music Heals Us (Part 1)
# 20                                                   You’re Not Alone in Feeling Lonely
# 21                Dr. Rangan Chatterjee: What's at the Core of Your Happiness? (Part 2)
# 14                             Rainn Wilson: Walking A Spiritual Path In A Lonely World
# 12           Encore | Susan Cain: How Do We Navigate the Joy and Sorrow of Being Human?
# 17                                   Judy Woodruff: What Does It Mean To Really Listen?
# 18                              Dr. Lisa Damour: How Can We Protect Teen Mental Health?
# 3                                   Matthew McConaughey: What Does Success Really Mean?
# 16                                        Meet My Moai, A Powerful Friendship Tradition
# 40                                              Dr. Laurie Santos: What Makes Us Happy?
# 2                              Jon Batiste: How Do You Build the Confidence to Connect?
# 15                      Richard Reeves: Why Are Boys And Men Struggling For Connection?
# 9                                          Ashley Judd & Friends: Finding Chosen Family
# 1                     Dr. Lisa Miller: How Does Spirituality Protect Our Mental Health?
# 6                                                 Yo-Yo Ma: How Music Heals Us (Part 2)
# 8                        Baratunde Thurston: What Can Nature Teach Us About Connection?
# 10                        Encore | Dr. Tracy Dennis-Tiwary: Can Anxiety Be Good For Us?
# 19                    Eric Nam: Yes, Vulnerability is a Superpower (Even For Pop Stars)
# 42                               Jon Kabat-Zinn: Peace and the Domain of Being (Part 1)
# 43                                 Father Greg Boyle: Finding Strength Through Kindness
# 24                                    Catherine Price: Can You Live Without Your Phone?
# 13                                          Encore | José Andrés: Recipe for Connection
# 29                            Dr. Marisa G. Franco: Why Do Friendships Matter? (Part 1)
# 4                                                                 How Will You Connect?
# 47                                         Welcome to House Calls with Dr. Vivek Murthy
# 5                        Encore (Student Edition) | Laurie Santos: What Makes Us Happy?
# 25                                                                 What Gives You Hope?
# 45                                  Kate Bowler: Learning to Live When Life Falls Apart
# 46                                                   José Andrés: Recipe for Connection
# 27                            Dr. Marisa G. Franco: Why Do Friendships Matter? (Part 2)
# 41                         Jon Kabat-Zinn: Clarity and the Domain of Stillness (Part 2)
# 0                                             Meditation for Connecting with Loved Ones
# 31                                                 Maya Shankar: Why is Change So Hard?
# 26                           Bonus: Meditation for Dealing with Negativity in the World
# 37                                  Dr. Becky Kennedy: How Do We Connect With Our Kids?
# 38                    Susan Cain: How Do We Navigate the Joy and Sorrow of Being Human?
# 35                                                              Fred Dust: Can We Talk?
# 28                                   Bonus: Meditation for Getting Through a Hectic Day
# 34                                 Dr. Tracy Dennis-Tiwary: Can Anxiety Be Good For Us?
# 39                                         Kal Penn: Taking the Path of Most Resistance
# 30                              Bonus: Meditation for Dealing with Change & Uncertainty
# 44                        Christian Robinson: Why Feeling Like We Matter Really Matters
# 32                                           Bonus: Meditation for Combating Loneliness
# 33                                          Bonus: Meditation for Easing Holiday Stress
# 36     Dr. Rosaura Orengo-Aguayo: What Do Natural Disasters Mean for Our Mental Health?
#
#     Times Fully Played
# 23             5003.12
# 11             3004.22
# 22             2979.86
# 7              2692.54
# 20             2538.95
# 21             2536.88
# 14             2402.13
# 12             2267.34
# 17             2144.28
# 18             2078.34
# 3              2052.19
# 16             1906.99
# 40             1850.23
# 2              1848.22
# 15             1837.18
# 9              1836.19
# 1              1830.16
# 6              1810.17
# 8              1809.12
# 10             1758.37
# 19             1631.77
# 42             1578.68
# 43             1562.65
# 24             1552.60
# 13             1502.74
# 29             1491.98
# 4              1491.63
# 47             1422.22
# 5              1389.04
# 25             1360.78
# 45             1152.74
# 46             1152.05
# 27             1116.29
# 41             1099.76
# 0              1005.88
# 31              998.28
# 26              996.31
# 37              942.14
# 38              898.33
# 35              850.91
# 28              786.98
# 34              730.95
# 39              726.09
# 30              720.00
# 44              714.57
# 32              576.00
# 33              384.73
# 36              349.17

# %% [markdown]
# # Cumulative Table

# %%
def calculate_platform_stats(df, latest):
    # Calculate All Platform Average Plays Per Episode
    all_platform_avg_plays = round(df['Total Combined Plays'].mean())

    # Calculate All Platform Total Plays
    all_platform_total_plays = df['Total Combined Plays'].sum()

    # Calculate All Audio Platform Plays
    all_audio_platform_plays = df['Total Podcast Plays'].sum()

    # Calculate All YouTube Plays
    all_youtube_plays = df['Total YouTube Plays'].sum()
    
    #df['Streams (S)'] = pd.to_numeric(df['Streams (S)'], errors='coerce') # PROBLEM
        
    # Calculate All Spotify Plays
    all_streams = df['Streams (S)'].sum()
    all_hours = df['Hours Played (S)'].sum()
    
    # Calculate All Apple Plays
    apple_engaged_listeners = df['Unique Engaged Listeners (A)'].sum()
    apple_total_time_listened = df['Hours Played (A)'].sum()


    # Extract only the date part from the datetime
    latest_date = latest.date()

    # Create a new DataFrame with the calculated statistics
    stats_df = pd.DataFrame({
    'Metric': ['All Platform Average Plays Per Episode',
               'All Platform Total Plays (Spotify, Apple, YouTube)',
               'All Audio Platform Plays (Spotify + Apple)',
               'All YouTube Plays', 
               'Spotify Listener Streams (60 seconds or more)', 
               'Spotify Consumption Hours',
               'Spotify  Followers',
               'Spotify Ratings',
               'Apple Engaged Listeners (20 minutes or >40%)',
               'Apple Total Time Listened (hours)',
               'Apple  Followers',
               'Apple Ratings'],  # Closing the list of metrics here
        
    latest_date: [int(all_platform_avg_plays), int(all_platform_total_plays),
                  int(all_audio_platform_plays), int(all_youtube_plays), int(all_streams),
                  int(all_hours), df["Followers (S)"].iloc[0], df["Spotify Rating"].iloc[0],  int(apple_engaged_listeners),
                  int(apple_total_time_listened), df["Followers (A)"].iloc[0], df["Apple Rating"].iloc[0]]
    })
    return stats_df

# %%
unique_dates = df["Date Collected"].unique()
unique_dates_sorted = sorted(unique_dates, reverse=True)
#latest = df["Date Collected"].max()
latest = unique_dates_sorted[0] if len(unique_dates_sorted) > 1 else None
latest1 = unique_dates_sorted[1] if len(unique_dates_sorted) > 1 else None
latest2 = unique_dates_sorted[2] if len(unique_dates_sorted) > 1 else None
latest3 = unique_dates_sorted[3] if len(unique_dates_sorted) > 1 else None
latest_df = df[df["Date Collected"] == latest]
latest_df1 = df[df["Date Collected"] == latest1]
latest_df2 = df[df["Date Collected"] == latest2]
latest_df3 = df[df["Date Collected"] == latest3]
df1 = calculate_platform_stats(latest_df, latest)
df2 = calculate_platform_stats(latest_df1, latest1)
df3 = calculate_platform_stats(latest_df2, latest2)
df4 = calculate_platform_stats(latest_df3, latest3)
concatenated_df = pd.concat([df4, df3, df2, df1], axis=1)
concatenated_df = concatenated_df.loc[:, ~concatenated_df.columns.duplicated()]
concatenated_df
# Out:
#                                                 Metric  2024-01-24  \
# 0               All Platform Average Plays Per Episode      7962.0
# 1   All Platform Total Plays (Spotify, Apple, YouTube)    366243.0
# 2           All Audio Platform Plays (Spotify + Apple)    220255.0
# 3                                    All YouTube Plays    145988.0
# 4        Spotify Listener Streams (60 seconds or more)     48828.0
# 5                            Spotify Consumption Hours     17447.0
# 6                                   Spotify  Followers         NaN
# 7                                      Spotify Ratings         NaN
# 8         Apple Engaged Listeners (20 minutes or >40%)     41645.0
# 9                    Apple Total Time Listened (hours)     38565.0
# 10                                    Apple  Followers         NaN
# 11                                       Apple Ratings         NaN
#
#     2024-01-29  2024-02-05 2024-02-14
# 0       7941.0      7655.0       8047
# 1     373212.0    359786.0     386246
# 2     226266.0    229427.0     236099
# 3     146946.0    148297.0     150147
# 4      49807.0     50896.0      52112
# 5      17925.0     18324.0      18725
# 6          NaN         NaN      4,303
# 7          NaN         NaN   4.9 (75)
# 8      42588.0     43272.0      44688
# 9      39651.0     40449.0      41260
# 10         NaN         NaN      6,357
# 11         NaN         NaN  4.9 (174)

# %% [markdown]
# # Cumulative Episode

# %%
last_eps = most_recent["#"].max() 
last_eps_df = most_recent[most_recent["#"] == last_eps]
last_eps_df
# Out:
#     #                              Episode Title  Total Combined Plays  \
# 0  47  Meditation for Connecting with Loved Ones                3737.0
#
#    Total Podcast Plays  Total YouTube Plays Duration  Times Played  \
# 0                 3533                204.0    04:32       1005.88
#
#   Median Play Time (S)  % Complete (S)  Total Hours Played  ...  \
# 0             00:04:31              76                76.0  ...
#
#    Unique Engaged Listeners (A)  Plays (A) Starts (S)  Streams (S)  \
# 0                         692.0     1486.0      356.0        256.0
#
#    Listeners (S)  Date Collected  Followers (A)  Followers (S)  \
# 0          295.0      2024-02-14          6,357          4,303
#
#    Spotify Rating Apple Rating
# 0        4.9 (75)    4.9 (174)
#
# [1 rows x 24 columns]
